# %% [markdown]
# <a href="https://colab.research.google.com/github/tejuuu-7774/GENAI_collabs/blob/main/ANN_NLP_VS_RNN_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANN VS RNN VS LSTM

# %%
# import numpy as np
# from tensorflow.keras.preprocessing.text import Tokenizer
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import SimpleRNN , Dense , Embedding , Flatten

# %%
# # Dataset chosen for TEXT ANALYSIS
# train_sentences = [
#     'The player scored a winning goal',      # Sports
#     'The team won the championship match',   # Sports
#     'He hit a massive home run',             # Sports
#     'The stock market price crashed down',   # Finance
#     'Invest your money in this bank',        # Finance
#     'Interest rates are very high today'     # Finance
# ]
# train_labels = np.array([1, 1, 1, 0, 0, 0])

# %%
# tokenizer = Tokenizer(oov_token='<OOV>')
# tokenizer.fit_on_texts(train_sentences)
# sequences = tokenizer.texts_to_sequences(train_sentences)

# %%
# # PADDING
# max_length = 8
# padded_data = pad_sequences(sequences, maxlen=max_length , padding='pre')

# %%
# print("Word : ", tokenizer.word_index)
# print("Padded data : ",padded_data)

# %%
# vocab_size = len(tokenizer.word_index) + 1
# print("Vocab size : ",vocab_size)

# ann_model = Sequential()
# ann_model.add(Embedding(input_dim=vocab_size , output_dim=8 , input_length=max_length))
# ann_model.add(Flatten())
# ann_model.add(Dense(1,activation='sigmoid'))

# print("ANN MODEL")
# ann_model.compile(loss='binary_crossentropy' , optimizer='adam',metrics=['accuracy'])
# ann_model.fit(padded_data, train_labels, epochs=200,verbose=0)

# %%
# rnn_model = Sequential()
# rnn_model.add(Embedding(input_dim=100 , output_dim=8))
# rnn_model.add(SimpleRNN(16))
# rnn_model.add(Dense(1,activation='sigmoid'))
# print("RNN MODEL")
# rnn_model.compile(loss='binary_crossentropy' , optimizer='adam',metrics=['accuracy'])
# rnn_model.fit(padded_data, train_labels, epochs=200,verbose=0)

# %%
# #  PREDICTING
# test_text = ["The player won the match"]
# test_seq = tokenizer.texts_to_sequences(test_text)
# test_pad = pad_sequences(test_seq , maxlen=max_length , padding='pre')

# # predict
# ann_pred = ann_model.predict(test_pad, verbose=0)[0][0]
# rnn_pred = rnn_model.predict(test_pad, verbose=0)[0][0]

# %%
# print(f"\nTest Sentence: '{test_text[0]}'")
# print(f"ANN Prediction: {ann_pred:.4f} (Raw Score)")
# print(f"RNN Prediction: {rnn_pred:.4f} (Raw Score)")

# # Decision Logic
# print(f"\nFinal Verdict:")
# print(f"ANN says: {'Sports' if ann_pred > 0.5 else 'Finance'}")
# print(f"RNN says: {'Sports' if rnn_pred > 0.5 else 'Finance'}")

# %%
# # LSTM ( LONG SHORT TERM MEMORY )
# from tensorflow.keras.layers import LSTM

# lstm_model = Sequential()
# lstm_model.add(Embedding(input_dim=vocab_size, output_dim=8, input_length=max_length))
# lstm_model.add(LSTM(16))
# lstm_model.add(Dense(1, activation='sigmoid'))

# print("LSTM MODEL")
# lstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# lstm_model.fit(padded_data, train_labels, epochs=200, verbose=0)

# lstm_pred = lstm_model.predict(test_pad, verbose=0)[0][0]

# print(f"LSTM Prediction: {lstm_pred:.4f} (Raw Score)")
# print(f"LSTM says: {'Sports' if lstm_pred > 0.5 else 'Finance'}")
